# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
#GAMMA = 0.95
GAMMA = 0.96
LEARNING_RATE = 0.001  
  
#MEMORY_SIZE = 1000000
MEMORY_SIZE = 1000000
BATCH_SIZE = 20  
  
#EXPLORATION_MAX = 1.0  
#EXPLORATION_MIN = 0.01  
#EXPLORATION_DECAY = 0.995 

EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.02  
EXPLORATION_DECAY = 0.995 
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
According to the article, "Cartpole: Introduction", the Cartpole is like an inverted penduleum that is kept centered by applying
various forces. In this example, the agrent picks the best one, take action and execute.The states include in the above example is 
state, action, reward, next_state and done. The agent goes through these states and execute the best among all.At first, agent and environment are 
created along with observer, the agent passed through all these states and complete steps.

The line:
    reward = reward if not terminal else -reward
explains more specifically about the whole cartpole, stating if the agent goes through all reward it otherwise do not reward and start
the whole process.

The terms like 'remember' and 'replay' used are examples of Deep learning. The deep natural artitecture for this example is:
    self.model = Sequential()  
    self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
    self.model.add(Dense(24, activation="relu"))  
    self.model.add(Dense(self.action_space, activation="linear"))  
    self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
the natural arttecture made the learning more efficient because they have same artitecture but different weights. In every step,
the weight of current step is copied for target weight.
# Out:
#   File "<ipython-input-6-08388b1363e8>", line 1
#     According to the article, "Cartpole: Introduction", the Cartpole is like an inverted penduleu that is kept centered by applying
#                ^
# SyntaxError: invalid syntax

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 15
# Scores: (min: 15, avg: 15, max: 15)
#
# Run: 2, exploration: 0.8348931673187264, score: 41
# Scores: (min: 15, avg: 28, max: 41)
#
# Run: 3, exploration: 0.7822236754458713, score: 14
# Scores: (min: 14, avg: 23.333333333333332, max: 41)
#
# Run: 4, exploration: 0.6832098777212641, score: 28
# Scores: (min: 14, avg: 24.5, max: 41)
#
# Run: 5, exploration: 0.6118738784280476, score: 23
# Scores: (min: 14, avg: 24.2, max: 41)
#
# Run: 6, exploration: 0.5819594443402982, score: 11
# Scores: (min: 11, avg: 22, max: 41)
#
# Run: 7, exploration: 0.510849320360386, score: 27
# Scores: (min: 11, avg: 22.714285714285715, max: 41)
#
# Run: 8, exploration: 0.4932355662165453, score: 8
# Scores: (min: 8, avg: 20.875, max: 41)
#
# Run: 9, exploration: 0.4738479773082268, score: 9
# Scores: (min: 8, avg: 19.555555555555557, max: 41)
#
# Run: 10, exploration: 0.446186062443672, score: 13
# Scores: (min: 8, avg: 18.9, max: 41)
#
# Run: 11, exploration: 0.41386834584198684, score: 16
# Scores: (min: 8, avg: 18.636363636363637, max: 41)
#
# Run: 12, exploration: 0.3877593341372176, score: 14
# Scores: (min: 8, avg: 18.25, max: 41)
#
# Run: 13, exploration: 0.36880183088056995, score: 11
# Scores: (min: 8, avg: 17.692307692307693, max: 41)
#
# Run: 14, exploration: 0.3507711574848344, score: 11
# Scores: (min: 8, avg: 17.214285714285715, max: 41)
#
# Run: 15, exploration: 0.33195389135223546, score: 12
# Scores: (min: 8, avg: 16.866666666666667, max: 41)
#
# Run: 16, exploration: 0.3157247089126454, score: 11
# Scores: (min: 8, avg: 16.5, max: 41)
#
# Run: 17, exploration: 0.29580711868545667, score: 14
# Scores: (min: 8, avg: 16.352941176470587, max: 41)
#
# Run: 18, exploration: 0.28134514724562876, score: 11
# Scores: (min: 8, avg: 16.055555555555557, max: 41)
#
# Run: 19, exploration: 0.26759021970270175, score: 11
# Scores: (min: 8, avg: 15.789473684210526, max: 41)
#
# Run: 20, exploration: 0.25450776877280124, score: 11
# Scores: (min: 8, avg: 15.55, max: 41)
#
# Run: 21, exploration: 0.24450384299593592, score: 9
# Scores: (min: 8, avg: 15.238095238095237, max: 41)
#
# Run: 22, exploration: 0.22566020663225933, score: 17
# Scores: (min: 8, avg: 15.318181818181818, max: 41)
#
# Run: 23, exploration: 0.2167901907234072, score: 9
# Scores: (min: 8, avg: 15.043478260869565, max: 41)
#
# Run: 24, exploration: 0.20619134658263935, score: 11
# Scores: (min: 8, avg: 14.875, max: 41)
#
# Run: 25, exploration: 0.1846622876013121, score: 23
# Scores: (min: 8, avg: 15.2, max: 41)
#
# Run: 26, exploration: 0.11470197137452155, score: 96
# Scores: (min: 8, avg: 18.307692307692307, max: 96)
#
# Run: 27, exploration: 0.09292664835904782, score: 43
# Scores: (min: 8, avg: 19.22222222222222, max: 96)
#
# Run: 28, exploration: 0.05517478773284426, score: 105
# Scores: (min: 8, avg: 22.285714285714285, max: 105)
#
# Run: 29, exploration: 0.046997986793891174, score: 33
# Scores: (min: 8, avg: 22.655172413793103, max: 105)
#
# Run: 30, exploration: 0.043159025252331236, score: 18
# Scores: (min: 8, avg: 22.5, max: 105)
#
# Run: 31, exploration: 0.03963364364733769, score: 18
# Scores: (min: 8, avg: 22.35483870967742, max: 105)
#
# Run: 32, exploration: 0.036396227662238566, score: 18
# Scores: (min: 8, avg: 22.21875, max: 105)
#
# Run: 33, exploration: 0.032595988006089364, score: 23
# Scores: (min: 8, avg: 22.242424242424242, max: 105)
#
# Run: 34, exploration: 0.029933432588273214, score: 18
# Scores: (min: 8, avg: 22.11764705882353, max: 105)
#
# Run: 35, exploration: 0.027350922279685573, score: 19
# Scores: (min: 8, avg: 22.02857142857143, max: 105)
#
# Run: 36, exploration: 0.025116802354115567, score: 18
# Scores: (min: 8, avg: 21.916666666666668, max: 105)
#
# Run: 37, exploration: 0.022158551474944856, score: 26
# Scores: (min: 8, avg: 22.027027027027028, max: 105)
#
# Run: 38, exploration: 0.020246819920648168, score: 19
# Scores: (min: 8, avg: 21.94736842105263, max: 105)
#
# Run: 39, exploration: 0.018780321875645996, score: 16
# Scores: (min: 8, avg: 21.794871794871796, max: 105)
#
# Run: 40, exploration: 0.016903931611681827, score: 22
# Scores: (min: 8, avg: 21.8, max: 105)
#
# Run: 41, exploration: 0.014042412118399107, score: 38
# Scores: (min: 8, avg: 22.195121951219512, max: 105)
#
# Run: 42, exploration: 0.012388500230681249, score: 26
# Scores: (min: 8, avg: 22.285714285714285, max: 105)
#
# Run: 43, exploration: 0.010087070213020206, score: 42
# Scores: (min: 8, avg: 22.74418604651163, max: 105)
#
# Run: 44, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 23.636363636363637, max: 105)
#
# Run: 45, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 24.155555555555555, max: 105)
#
# Run: 46, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 24.456521739130434, max: 105)
#
# Run: 47, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 24.872340425531913, max: 105)
#
# Run: 48, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 25.479166666666668, max: 105)
#
# Run: 49, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 25.959183673469386, max: 105)
#
# Run: 50, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 26.72, max: 105)
#
# Run: 51, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 27.19607843137255, max: 105)
#
# Run: 52, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 29.192307692307693, max: 131)
#
# Run: 53, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 30.79245283018868, max: 131)
#
# Run: 54, exploration: 0.01, score: 332
# Scores: (min: 8, avg: 36.370370370370374, max: 332)
#
# Run: 55, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 39.03636363636364, max: 332)
#
# Run: 56, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 42.25, max: 332)
#
# Run: 57, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 44.85964912280702, max: 332)
#
# Run: 58, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 47.13793103448276, max: 332)
#
# Run: 59, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 49.25423728813559, max: 332)
#
# Run: 60, exploration: 0.01, score: 296
# Scores: (min: 8, avg: 53.36666666666667, max: 332)
#
# Run: 61, exploration: 0.01, score: 266
# Scores: (min: 8, avg: 56.85245901639344, max: 332)
#
# Run: 62, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 58.806451612903224, max: 332)
#
# Run: 63, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 60.38095238095238, max: 332)
#
# Run: 64, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 61.03125, max: 332)
#
# Run: 65, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 63.215384615384615, max: 332)
#
# Run: 66, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 65.28787878787878, max: 332)
#
# Run: 67, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 66.88059701492537, max: 332)
#
# Run: 68, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 68.01470588235294, max: 332)
#
# Run: 69, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 69.3913043478261, max: 332)
#
# Run: 70, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 70.68571428571428, max: 332)
#
# Run: 71, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 72.15492957746478, max: 332)
#
# Run: 72, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 73.44444444444444, max: 332)
#
# Run: 73, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 74.86301369863014, max: 332)
#
# Run: 74, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 76.32432432432432, max: 332)
#
# Run: 75, exploration: 0.01, score: 244
# Scores: (min: 8, avg: 78.56, max: 332)
#
# Run: 76, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 79.82894736842105, max: 332)
#
# Run: 77, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 81.1038961038961, max: 332)
#
# Run: 78, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 82.17948717948718, max: 332)
#
# Run: 79, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 83.18987341772151, max: 332)
#
# Run: 80, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 84.0875, max: 332)
#
# Run: 81, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 85.09876543209876, max: 332)
#
# Run: 82, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 86.32926829268293, max: 332)
#
# Run: 83, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 87.62650602409639, max: 332)
#
# Run: 84, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 88.67857142857143, max: 332)
#
# Run: 85, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 89.83529411764705, max: 332)
#
# Run: 86, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 90.6046511627907, max: 332)
#
# Run: 87, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 92.9080459770115, max: 332)
# Run: 88, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 93.8409090909091, max: 332)
#
# Run: 89, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 94.48314606741573, max: 332)
#
# Run: 90, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 95.12222222222222, max: 332)
#
# Run: 91, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 96.17582417582418, max: 332)
#
# Run: 92, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 96.78260869565217, max: 332)
#
# Run: 93, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 97.83870967741936, max: 332)
#
# Run: 94, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 98.8936170212766, max: 332)
#
# Run: 95, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 99.89473684210526, max: 332)
#
# Run: 96, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 100.45833333333333, max: 332)
#
# Run: 97, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 100.85567010309278, max: 332)
#
# Run: 98, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 101.94897959183673, max: 332)
#
# Run: 99, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 102.92929292929293, max: 332)
#
# Run: 100, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 103.81, max: 332)
#
# Run: 101, exploration: 0.01, score: 220
# Scores: (min: 8, avg: 105.86, max: 332)
#
# Run: 102, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 106.95, max: 332)
#
# Run: 103, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 108.15, max: 332)
#
# Run: 104, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 109.19, max: 332)
#
# Run: 105, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 110.77, max: 332)
#
# Run: 106, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 112.01, max: 332)
#
# Run: 107, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 113, max: 332)
#
# Run: 108, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 114.58, max: 332)
#
# Run: 109, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 116.32, max: 332)
#
# Run: 110, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 117.87, max: 332)
#
# Run: 111, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 119.31, max: 332)
#
# Run: 112, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 120.37, max: 332)
#
# Run: 113, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 121.66, max: 332)
#
# Run: 114, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 123.28, max: 332)
#
# Run: 115, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 125.13, max: 332)
#
# Run: 116, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 126.75, max: 332)
#
# Run: 117, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 128.22, max: 332)
#
# Run: 118, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 128.78, max: 332)
#
# Run: 119, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 128.76, max: 332)
#
# Run: 120, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 128.74, max: 332)
#
# Run: 121, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 128.75, max: 332)
#
# Run: 122, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 128.68, max: 332)
#
# Run: 123, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 128.68, max: 332)
#
# Run: 124, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 128.67, max: 332)
#
# Run: 125, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 128.54, max: 332)
#
# Run: 126, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 127.68, max: 332)
#
# Run: 127, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 127.35, max: 332)
#
# Run: 128, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 126.39, max: 332)
#
# Run: 129, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 126.14, max: 332)
#
# Run: 130, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 126.06, max: 332)
#
# Run: 131, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 125.98, max: 332)
#
# Run: 132, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 125.88, max: 332)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 125.75, max: 332)
#
# Run: 134, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 125.66, max: 332)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 125.57, max: 332)
#
# Run: 136, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 125.49, max: 332)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 125.33, max: 332)
#
# Run: 138, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 126.67, max: 332)
#
# Run: 139, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 127.77, max: 332)
#
# Run: 140, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 128.97, max: 332)
#
# Run: 141, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 130.03, max: 332)
#
# Run: 142, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 131.37, max: 332)
#
# Run: 143, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 132.81, max: 332)
#
# Run: 144, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 133.71, max: 332)
#
# Run: 145, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 135.02, max: 332)
#
# Run: 146, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 136.07, max: 332)
#
# Run: 147, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 137.49, max: 332)
#
# Run: 148, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 138.68, max: 332)
#
# Run: 149, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 139.79, max: 332)
#
# Run: 150, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 140.79, max: 332)
#
# Run: 151, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 142.02, max: 332)
#
# Run: 152, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 142.29, max: 332)
#
# Run: 153, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 142.55, max: 332)
#
# Run: 154, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 140.73, max: 296)
#
# Run: 155, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 140.16, max: 296)
#
# Run: 156, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 139.3, max: 296)
#
# Run: 157, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 138.94, max: 296)
#
# Run: 158, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 138.42, max: 296)
#
# Run: 159, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 136.82, max: 296)
#
# Run: 160, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 135.27, max: 291)
#
# Run: 161, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 132.72, max: 291)
#
# Run: 162, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 131.05, max: 291)
#
# Run: 163, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 129.6, max: 291)
#
# Run: 164, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 128.7, max: 291)
#
# Run: 165, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 128.38, max: 291)
#
# Run: 166, exploration: 0.01, score: 262
# Scores: (min: 8, avg: 129, max: 291)
#
# Run: 167, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 128.97, max: 291)
#
# Run: 168, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 128.94, max: 291)
#
# Run: 169, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 129.03, max: 291)
#
# Run: 170, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 128.72, max: 291)
#
# Run: 171, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 128.52, max: 291)
#
# Run: 172, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 128.04, max: 291)
#
# Run: 173, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 127.82, max: 291)
#
# Run: 174, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 127.42, max: 291)
#
# Run: 175, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 126.77, max: 291)
#
# Run: 176, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 126.65, max: 291)
#
# Run: 177, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 126.82, max: 291)
#
# Run: 178, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 126.93, max: 291)
#
# Run: 179, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 126.33, max: 291)
#
# Run: 180, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 126.22, max: 291)
#
# Run: 181, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 126.11, max: 291)
#
# Run: 182, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 125.54, max: 291)
#
# Run: 183, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 125.61, max: 291)
#
# Run: 184, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 125.19, max: 291)
#
# Run: 185, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 124.67, max: 291)
#
# Run: 186, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 124.59, max: 291)
#
# Run: 187, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 123.19, max: 262)
#
# Run: 188, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 122.81, max: 262)
# Run: 189, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 122.62, max: 262)
#
# Run: 190, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 122.49, max: 262)
#
# Run: 191, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 122.5, max: 262)
#
# Run: 192, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 122.64, max: 262)
#
# Run: 193, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 122.33, max: 262)
#
# Run: 194, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 121.83, max: 262)
#
# Run: 195, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 121.57, max: 262)
#
# Run: 196, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 121.45, max: 262)
#
# Run: 197, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 121.47, max: 262)
#
# Run: 198, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 121.84, max: 262)
#
# Run: 199, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 121.33, max: 262)
#
# Run: 200, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 121.19, max: 262)
#
# Run: 201, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 120.77, max: 262)
#
# Run: 202, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 120.71, max: 262)
#
# Run: 203, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 120.59, max: 262)
#
# Run: 204, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 121.01, max: 262)
#
# Run: 205, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 119.89, max: 262)
#
# Run: 206, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 120.28, max: 262)
#
# Run: 207, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 120.84, max: 262)
#
# Run: 208, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 120.58, max: 262)
#
# Run: 209, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 120.97, max: 262)
#
# Run: 210, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 120.77, max: 262)
#
# Run: 211, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 120.69, max: 262)
#
# Run: 212, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 121.02, max: 262)
#
# Run: 213, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 121.38, max: 262)
#
# Run: 214, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 121.18, max: 262)
#
# Run: 215, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 120.86, max: 262)
#
# Run: 216, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 121.32, max: 262)
#
# Run: 217, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 121.12, max: 262)
#
# Run: 218, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 122.33, max: 262)
#
# Run: 219, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 123.57, max: 262)
#
# Run: 220, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 124.91, max: 262)
#
# Run: 221, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 126.7, max: 262)
#
# Run: 222, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 128.07, max: 262)
#
# Run: 223, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 129.96, max: 262)
#
# Run: 224, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 131.46, max: 262)
#
# Run: 225, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 132.78, max: 262)
#
# Run: 226, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 134.38, max: 262)
#
# Run: 227, exploration: 0.01, score: 351
# Scores: (min: 8, avg: 137.79, max: 351)
#
# Run: 228, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 139.26, max: 351)
#
# Run: 229, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 139.31, max: 351)
#
# Run: 230, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 139.32, max: 351)
#
# Run: 231, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 139.47, max: 351)
#
# Run: 232, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 139.49, max: 351)
#
# Run: 233, exploration: 0.01, score: 268
# Scores: (min: 9, avg: 142.07, max: 351)
#
# Run: 234, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 143.68, max: 351)
#
# Run: 235, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 145.07, max: 351)
#
# Run: 236, exploration: 0.01, score: 273
# Scores: (min: 10, avg: 147.7, max: 351)
#
# Run: 237, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 149.38, max: 351)
#
# Run: 238, exploration: 0.01, score: 277
# Scores: (min: 10, avg: 150.62, max: 351)
#
# Run: 239, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 150.68, max: 351)
#
# Run: 240, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 151.53, max: 351)
#
# Run: 241, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 152.15, max: 351)
#
# Run: 242, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 152.1, max: 351)
#
# Run: 243, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 151.71, max: 351)
#
# Run: 244, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 151.69, max: 351)
#
# Run: 245, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 151.34, max: 351)
#
# Run: 246, exploration: 0.01, score: 299
# Scores: (min: 10, avg: 152.9, max: 351)
#
# Run: 247, exploration: 0.01, score: 401
# Scores: (min: 10, avg: 155.05, max: 401)
#
# Run: 248, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 154.3, max: 401)
#
# Run: 249, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 154.37, max: 401)
#
# Run: 250, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 154.26, max: 401)
#
# Run: 251, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 153.56, max: 401)
#
# Run: 252, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 154.25, max: 401)
#
# Run: 253, exploration: 0.01, score: 189
# Scores: (min: 10, avg: 154.74, max: 401)
#
# Run: 254, exploration: 0.01, score: 205
# Scores: (min: 10, avg: 155.29, max: 401)
#
# Run: 255, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 155.35, max: 401)
#
# Run: 256, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 155.65, max: 401)
#
# Run: 257, exploration: 0.01, score: 442
# Scores: (min: 10, avg: 158.52, max: 442)
#
# Run: 258, exploration: 0.01, score: 188
# Scores: (min: 10, avg: 159.15, max: 442)
#
# Run: 259, exploration: 0.01, score: 278
# Scores: (min: 10, avg: 161.81, max: 442)
#
# Run: 260, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 162.17, max: 442)
#
# Run: 261, exploration: 0.01, score: 253
# Scores: (min: 10, avg: 164.59, max: 442)
#
# Run: 262, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 166.83, max: 442)
#
# Run: 263, exploration: 0.01, score: 321
# Scores: (min: 10, avg: 169.91, max: 442)
#
# Run: 264, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 171.61, max: 442)
#
# Run: 265, exploration: 0.01, score: 280
# Scores: (min: 10, avg: 172.7, max: 442)
#
# Run: 266, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 171.57, max: 442)
#
# Run: 267, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 171.45, max: 442)
#
# Run: 268, exploration: 0.01, score: 221
# Scores: (min: 10, avg: 172.25, max: 442)
#
# Run: 269, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 171.81, max: 442)
#
# Run: 270, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 171.22, max: 442)
#
# Run: 271, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 171.58, max: 442)
#
# Run: 272, exploration: 0.01, score: 234
# Scores: (min: 10, avg: 172.75, max: 442)
#
# Run: 273, exploration: 0.01, score: 318
# Scores: (min: 10, avg: 174.38, max: 442)
#
# Run: 274, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 174.26, max: 442)
#
# Run: 275, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 173.9, max: 442)
#
# Run: 276, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 173.95, max: 442)
#
# Run: 277, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 173.38, max: 442)
#
# Run: 278, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 173.17, max: 442)
#
# Run: 279, exploration: 0.01, score: 328
# Scores: (min: 10, avg: 175.43, max: 442)
#
# Run: 280, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 174.65, max: 442)
#
# Run: 281, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 174.12, max: 442)
#
# Run: 282, exploration: 0.01, score: 355
# Scores: (min: 10, avg: 176.38, max: 442)
#
# Run: 283, exploration: 0.01, score: 290
# Scores: (min: 10, avg: 177.27, max: 442)
#
# Run: 284, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 177.75, max: 442)
#
# Run: 285, exploration: 0.01, score: 330
# Scores: (min: 10, avg: 179.7, max: 442)
#
# Run: 286, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 180.68, max: 442)
#
# Run: 287, exploration: 0.01, score: 247
# Scores: (min: 10, avg: 181.64, max: 442)
#
# Run: 288, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 182.38, max: 442)
#
# Run: 289, exploration: 0.01, score: 249
# Scores: (min: 10, avg: 183.55, max: 442)
# Run: 290, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 182.61, max: 442)
#
# Run: 291, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 182.29, max: 442)
#
# Run: 292, exploration: 0.01, score: 320
# Scores: (min: 10, avg: 183.83, max: 442)
#
# Run: 293, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 184, max: 442)
#
# Run: 294, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 187.53, max: 500)
#
# Run: 295, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 187.31, max: 500)
#
# Run: 296, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 187.25, max: 500)
#
# Run: 297, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 187.39, max: 500)
#
# Run: 298, exploration: 0.01, score: 266
# Scores: (min: 10, avg: 187.6, max: 500)
#
# Run: 299, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 187.47, max: 500)
#
# Run: 300, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 187, max: 500)
#
# Run: 301, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 187.02, max: 500)
#
# Run: 302, exploration: 0.01, score: 213
# Scores: (min: 10, avg: 187.71, max: 500)
#
# Run: 303, exploration: 0.01, score: 223
# Scores: (min: 10, avg: 188.72, max: 500)
#
# Run: 304, exploration: 0.01, score: 249
# Scores: (min: 10, avg: 189.47, max: 500)
#
# Run: 305, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 190.62, max: 500)
#
# Run: 306, exploration: 0.01, score: 241
# Scores: (min: 10, avg: 191.29, max: 500)
#
# Run: 307, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 191.17, max: 500)
#
# Run: 308, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 191.22, max: 500)
#
# Run: 309, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 190.59, max: 500)
#
# Run: 310, exploration: 0.01, score: 307
# Scores: (min: 10, avg: 192.18, max: 500)
#
# Run: 311, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 191.84, max: 500)
#
# Run: 312, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 191.79, max: 500)
#
# Run: 313, exploration: 0.01, score: 279
# Scores: (min: 10, avg: 192.82, max: 500)
#
# Run: 314, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 192.77, max: 500)
#
# Run: 315, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 191.24, max: 500)
#
# Run: 316, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 189.17, max: 500)
#
# Run: 317, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 187.86, max: 500)
#
# Run: 318, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 186.07, max: 500)
#
# Run: 319, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 184.91, max: 500)
#
# Run: 320, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 183.77, max: 500)
#
# Run: 321, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 182.89, max: 500)
#
# Run: 322, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 183.85, max: 500)
#
# Run: 323, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 183.31, max: 500)
#
# Run: 324, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 183.07, max: 500)
#
# Run: 325, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 181.81, max: 500)
#
# Run: 326, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 181.99, max: 500)
#
# Run: 327, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 179.37, max: 500)
#
# Run: 328, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 177.95, max: 500)
#
# Run: 329, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 178.18, max: 500)
#
# Run: 330, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 178.23, max: 500)
#
# Run: 331, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 178.19, max: 500)
#
# Run: 332, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 179.13, max: 500)
#
# Run: 333, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 177.54, max: 500)
#
# Run: 334, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 176.74, max: 500)
#
# Run: 335, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 176.46, max: 500)
#
# Run: 336, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 174.89, max: 500)
#
# Run: 337, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 174.28, max: 500)
#
# Run: 338, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 172.66, max: 500)
#
# Run: 339, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 172.67, max: 500)
#
# Run: 340, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 171.74, max: 500)
#
# Run: 341, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 170.92, max: 500)
#
# Run: 342, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 170.08, max: 500)
#
# Run: 343, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 169.23, max: 500)
#
# Run: 344, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 169.25, max: 500)
#
# Run: 345, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 169.57, max: 500)
#
# Run: 346, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 168.83, max: 500)
#
# Run: 347, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 166.31, max: 500)
#
# Run: 348, exploration: 0.01, score: 210
# Scores: (min: 9, avg: 167.43, max: 500)
#
# Run: 349, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 167.29, max: 500)
#
# Run: 350, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 165.98, max: 500)
#
# Run: 351, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 166.02, max: 500)
#
# Run: 352, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 165.18, max: 500)
#
# Run: 353, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 164.39, max: 500)
#
# Run: 354, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 163.04, max: 500)
#
# Run: 355, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 163.04, max: 500)
#
# Run: 356, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 161.78, max: 500)
#
# Run: 357, exploration: 0.01, score: 337
# Scores: (min: 9, avg: 160.73, max: 500)
#
# Run: 358, exploration: 0.01, score: 339
# Scores: (min: 9, avg: 162.24, max: 500)
#
# Run: 359, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 161.47, max: 500)
#
# Run: 360, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 160.97, max: 500)
#
# Run: 361, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 159.54, max: 500)
#
# Run: 362, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 158.61, max: 500)
#
# Run: 363, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 157.49, max: 500)
#
# Run: 364, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 156.86, max: 500)
#
# Run: 365, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 155.77, max: 500)
#
# Run: 366, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 154.91, max: 500)
#
# Run: 367, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 158.34, max: 500)
#
# Run: 368, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 157.53, max: 500)
#
# Run: 369, exploration: 0.01, score: 288
# Scores: (min: 9, avg: 159.13, max: 500)
#
# Run: 370, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 159.89, max: 500)
#
# Run: 371, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 159.87, max: 500)
#
# Run: 372, exploration: 0.01, score: 426
# Scores: (min: 9, avg: 161.79, max: 500)
#
# Run: 373, exploration: 0.01, score: 289
# Scores: (min: 9, avg: 161.5, max: 500)
#
# Run: 374, exploration: 0.01, score: 298
# Scores: (min: 9, avg: 163.17, max: 500)
#
# Run: 375, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 164.07, max: 500)
#
# Run: 376, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 163.84, max: 500)
#
# Run: 377, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 164.5, max: 500)
#
# Run: 378, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 164.04, max: 500)
#
# Run: 379, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 162.72, max: 500)
#
# Run: 380, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 163.21, max: 500)
#
# Run: 381, exploration: 0.01, score: 438
# Scores: (min: 9, avg: 166.57, max: 500)
#
# Run: 382, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 164.19, max: 500)
#
# Run: 383, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 163.29, max: 500)
#
# Run: 384, exploration: 0.01, score: 353
# Scores: (min: 9, avg: 165, max: 500)
#
# Run: 385, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 163.59, max: 500)
#
# Run: 386, exploration: 0.01, score: 368
# Scores: (min: 9, avg: 164.81, max: 500)
#
# Run: 387, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 163.57, max: 500)
#
# Run: 388, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 163.72, max: 500)
#
# Run: 389, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 162.76, max: 500)
#
# Run: 390, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 164.16, max: 500)
#
# Run: 391, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 164.01, max: 500)
# Run: 392, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 162.14, max: 500)
#
# Run: 393, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 162.1, max: 500)
#
# Run: 394, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 159.01, max: 500)
#
# Run: 395, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 158.54, max: 500)
#
# Run: 396, exploration: 0.01, score: 414
# Scores: (min: 9, avg: 161.32, max: 500)
#
# Run: 397, exploration: 0.01, score: 301
# Scores: (min: 9, avg: 162.78, max: 500)
#
# Run: 398, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 161.33, max: 500)
#
# Run: 399, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 161.44, max: 500)
#
# Run: 400, exploration: 0.01, score: 394
# Scores: (min: 9, avg: 164.08, max: 500)
#
# Run: 401, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 164.34, max: 500)
#
# Run: 402, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 163.79, max: 500)
#
# Run: 403, exploration: 0.01, score: 256
# Scores: (min: 9, avg: 164.12, max: 500)
#
# Run: 404, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 163.11, max: 500)
#
# Run: 405, exploration: 0.01, score: 279
# Scores: (min: 9, avg: 164.06, max: 500)
#
# Run: 406, exploration: 0.01, score: 323
# Scores: (min: 9, avg: 164.88, max: 500)
#
# Run: 407, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 164.22, max: 500)
#
# Run: 408, exploration: 0.01, score: 425
# Scores: (min: 9, avg: 167.02, max: 500)
#
# Run: 409, exploration: 0.01, score: 300
# Scores: (min: 9, avg: 168.43, max: 500)
#
# Run: 410, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 167.1, max: 500)
#
# Run: 411, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 168.64, max: 500)
#
# Run: 412, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 168.26, max: 500)
#
# Run: 413, exploration: 0.01, score: 284
# Scores: (min: 9, avg: 168.31, max: 500)
#
# Run: 414, exploration: 0.01, score: 317
# Scores: (min: 9, avg: 170, max: 500)
#
# Run: 415, exploration: 0.01, score: 380
# Scores: (min: 9, avg: 173.68, max: 500)
#
# Run: 416, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 175.46, max: 500)
#
# Run: 417, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 177.79, max: 500)
#
# Run: 418, exploration: 0.01, score: 143
# Scores: (min: 14, avg: 179.13, max: 500)
#
# Run: 419, exploration: 0.01, score: 300
# Scores: (min: 14, avg: 181.96, max: 500)
#
# Run: 420, exploration: 0.01, score: 117
# Scores: (min: 14, avg: 182.84, max: 500)
#
# Run: 421, exploration: 0.01, score: 131
# Scores: (min: 14, avg: 183.14, max: 500)
#
# Run: 422, exploration: 0.01, score: 184
# Scores: (min: 14, avg: 182.55, max: 500)
#
# Run: 423, exploration: 0.01, score: 145
# Scores: (min: 14, avg: 182.56, max: 500)
#
# Run: 424, exploration: 0.01, score: 301
# Scores: (min: 14, avg: 184.21, max: 500)
#
# Run: 425, exploration: 0.01, score: 185
# Scores: (min: 14, avg: 185.9, max: 500)
#
# Run: 426, exploration: 0.01, score: 284
# Scores: (min: 14, avg: 186.86, max: 500)
#
# Run: 427, exploration: 0.01, score: 215
# Scores: (min: 14, avg: 188.12, max: 500)
#
# Run: 428, exploration: 0.01, score: 312
# Scores: (min: 16, avg: 191.1, max: 500)
#
# Run: 429, exploration: 0.01, score: 340
# Scores: (min: 16, avg: 194.14, max: 500)
#
# Run: 430, exploration: 0.01, score: 292
# Scores: (min: 21, avg: 196.9, max: 500)
#
# Solved in 330 runs, 430 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.
